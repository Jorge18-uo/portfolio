# %%
print("warhamer 40k")

automoviles = ['El imperio', 'Los orkos', 'Eldars', 'tiranidos']

1
for waaaag in automoviles:
  if waaaag == 'El imperio':
    print(waaaag.upper('felicidades eres un narcisista,xenofobo,fanatico religioso,rasista,culpado de crimenes de guerra y muchas cosas orripilantes pero por lo menos se ven cool :D'))
2
for waaaag in automoviles:
  if waaaag == 'Los orkos':
    print(waaaag.upper('felicidades ahora ere uno de los chicos ,los seres mas divertidos de la galaxia'))
3
for waaaag in automoviles:
  if waaaag == 'Eldars':
    print(waaaag.upper('eres un depravado lugurios al que lo consume la luguria de slanesh a no mas poder y buscaras solo tu satisfaccion y el dolor de los demas'))
4
for waaaag in automoviles:
  if waaaag == 'tiranidos':
    print(waaaag.upper('tu sed de comer es insasible y no podras de masacrar mundos enteros en pocas palabras ñam ñam'))
# Out:
# warhamer 40k
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ab4af16fb3ee> in <cell line: 6>()
#       6 for waaaag in automoviles:
#       7   if waaaag == 'El imperio':
# ----> 8     print(waaaag.upper('felicidades eres un narcisista,xenofobo,fanatico religioso,rasista,culpado de crimenes de guerra y muchas cosas orripilantes pero por lo menos se ven cool :D'))
#       9 2
#      10 for waaaag in automoviles:
#
# TypeError: str.upper() takes no arguments (1 given)
